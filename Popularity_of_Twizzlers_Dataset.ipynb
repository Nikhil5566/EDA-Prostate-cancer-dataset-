# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Popularity_of_Twizzlers_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('TwizzlerData.csv')
df.head(11)
# Out:
#              Timestamp  TwizzlerRating TwizzlerFrequency            Race  \
# 0   6/13/2025 11:52:01               4       <1 per year           White
# 1   6/13/2025 11:56:32               1       <1 per year           White
# 2   6/13/2025 11:59:12               5        1 per year      East Asian
# 3   6/13/2025 12:02:17               1       <1 per year           White
# 4   6/13/2025 12:04:48               2       1 per month          Indian
# 5   6/13/2025 12:04:49               3        1 per year         Indian
# 6   6/13/2025 12:11:29               3       <1 per year  Middle Eastern
# 7   6/13/2025 12:12:48               5       <1 per year           White
# 8   6/13/2025 12:13:16               3        1 per year           White
# 9   6/13/2025 12:18:19               2        1 per year           White
# 10  6/13/2025 12:20:14               6       <1 per year      East Asian
#
#     Gender   Income Education  SleepHours  WorkHoursPerWeek
# ...

# %%
df.tail(11)
# Out:
#              Timestamp  TwizzlerRating TwizzlerFrequency        Race  \
# 42  6/13/2025 13:13:33               1       <1 per year    Hispanic
# 43  6/13/2025 13:14:39               2       <1 per year      Indian
# 44  6/13/2025 13:14:59               0       <1 per year      Indian
# 45  6/13/2025 13:15:51              10       1 per month    Hispanic
# 46  6/13/2025 13:16:37               2       <1 per year  East Asian
# 47  6/13/2025 13:17:43               2        1 per year  East Asian
# 48  6/13/2025 13:32:59               7        1 per year       White
# 49  6/13/2025 14:04:17               7        1 per year      Indian
# 50  6/13/2025 14:05:28               6       1 per month       White
# 51  6/13/2025 14:17:31               5       1 per month      Indian
# 52  6/13/2025 14:24:31               6       >1 per week      Indian
#
#         Gender    Income Education  SleepHours  WorkHoursPerWeek
# 42        Male      <70k       <HS         3.0                 0
# ...

# %%
df.shape
# Out:
# (53, 9)

# %%
df.columns
# Out:
# Index(['Timestamp', 'TwizzlerRating', 'TwizzlerFrequency', 'Race', 'Gender',
#        'Income', 'Education', 'SleepHours', 'WorkHoursPerWeek'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Timestamp             object
# TwizzlerRating         int64
# TwizzlerFrequency     object
# Race                  object
# Gender                object
# Income                object
# Education             object
# SleepHours           float64
# WorkHoursPerWeek       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          53 non-null     object
#  1   TwizzlerRating     53 non-null     int64
#  2   TwizzlerFrequency  52 non-null     object
#  3   Race               52 non-null     object
#  4   Gender             52 non-null     object
#  5   Income             45 non-null     object
#  6   Education          53 non-null     object
#  7   SleepHours         52 non-null     float64
#  8   WorkHoursPerWeek   53 non-null     int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 3.9+ KB

# %%
df.describe(include = 'all')
# Out:
#                  Timestamp  TwizzlerRating TwizzlerFrequency        Race  \
# count                   53       53.000000                52          52
# unique                  52             NaN                 6           7
# top     6/13/2025 12:42:48             NaN       <1 per year  East Asian
# freq                     2             NaN                27          17
# mean                   NaN        3.660377               NaN         NaN
# std                    NaN        2.752226               NaN         NaN
# min                    NaN        0.000000               NaN         NaN
# 25%                    NaN        1.000000               NaN         NaN
# 50%                    NaN        3.000000               NaN         NaN
# 75%                    NaN        6.000000               NaN         NaN
# max                    NaN       10.000000               NaN         NaN
#
#         Gender Income Education  SleepHours  WorkHoursPerWeek
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp            0
# TwizzlerRating       0
# TwizzlerFrequency    1
# Race                 1
# Gender               1
# Income               8
# Education            0
# SleepHours           1
# WorkHoursPerWeek     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling Outliers

# %%
Q1 = df['WorkHoursPerWeek'].quantile(0.25)
Q3 = df['WorkHoursPerWeek'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['WorkHoursPerWeek'] >= lower_bound) & (df['WorkHoursPerWeek'] <= upper_bound)].copy()

print('Before removing outliers:', len(df))
print('After removing outliers:', len(df_outliers))
# Out:
# Before removing outliers: 53
# After removing outliers: 53

# %% [markdown]
# # Univariate Analysis

# %%
# Get a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(15, 8))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Get a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Temporarily disable mathtext parsing for tick labels
plt.rcParams['text.usetex'] = False

for col in categorical_cols:
    plt.figure(figsize=(15, 8))
    sns.countplot(data=df, x=df[col].astype(str))
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Bivariate Analysis

# Get a list of numerical and categorical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Numerical vs. Numerical (Scatter plots)
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=numerical_cols[i], y=numerical_cols[j])
        plt.title(f'Scatter plot of {numerical_cols[i]} vs {numerical_cols[j]}')
        plt.xlabel(numerical_cols[i])
        plt.ylabel(numerical_cols[j])
        plt.show()

# Categorical vs. Categorical (Count plots or heatmaps of cross-tabulations)
for i in range(len(categorical_cols)):
    for j in range(i + 1, len(categorical_cols)):
        plt.figure(figsize=(12, 8))
        sns.countplot(data=df, x=categorical_cols[i], hue=categorical_cols[j])
        plt.title(f'Count plot of {categorical_cols[i]} by {categorical_cols[j]}')
        plt.xlabel(categorical_cols[i])
        plt.ylabel('Count')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# Numerical vs. Categorical (Box plots)
for num_col in numerical_cols:
    for cat_col in categorical_cols:
        plt.figure(figsize=(12, 8))
        sns.boxplot(data=df, x=cat_col, y=num_col)
        plt.title(f'Box plot of {num_col} by {cat_col}')
        plt.xlabel(cat_col)
        plt.ylabel(num_col)
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
