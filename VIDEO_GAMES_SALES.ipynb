# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/VIDEO_GAMES_SALES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Combined both the dataset:

DS1 = pd.read_csv('vg_data_dictionary.csv')
DS2 = pd.read_csv('vgchartz-2024.csv')

df = pd.concat([DS1, DS2], ignore_index = True)

df.to_csv('df.csv', index = False)

# %%
data = pd.read_csv('df.csv')
data.head(11)
# Out:
#            Field                                     Description  img title  \
# 0            img        URL slug for the box art at vgchartz.com  NaN   NaN
# 1          title                                      Game title  NaN   NaN
# 2        console               Console the game was released for  NaN   NaN
# 3          genre                               Genre of the game  NaN   NaN
# 4      publisher                           Publisher of the game  NaN   NaN
# 5      developer                           Developer of the game  NaN   NaN
# 6   critic_score                    Metacritic score (out of 10)  NaN   NaN
# 7    total_sales              Global sales of copies in millions  NaN   NaN
# 8       na_sales      North American sales of copies in millions  NaN   NaN
# 9       jp_sales            Japanese sales of copies in millions  NaN   NaN
# 10     pal_sales  European & African sales of copies in millions  NaN   NaN
#
#    console genre publisher developer  critic_score  total_sales  na_sales  \
# 0      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 1      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 2      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 3      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 4      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 5      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 6      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 7      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 8      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 9      NaN   NaN       NaN       NaN           NaN          NaN       NaN
# 10     NaN   NaN       NaN       NaN           NaN          NaN       NaN
#
#     jp_sales  pal_sales  other_sales release_date last_update
# 0        NaN        NaN          NaN          NaN         NaN
# 1        NaN        NaN          NaN          NaN         NaN
# 2        NaN        NaN          NaN          NaN         NaN
# 3        NaN        NaN          NaN          NaN         NaN
# 4        NaN        NaN          NaN          NaN         NaN
# 5        NaN        NaN          NaN          NaN         NaN
# 6        NaN        NaN          NaN          NaN         NaN
# 7        NaN        NaN          NaN          NaN         NaN
# 8        NaN        NaN          NaN          NaN         NaN
# 9        NaN        NaN          NaN          NaN         NaN
# 10       NaN        NaN          NaN          NaN         NaN

# %%
data.tail(11)
# Out:
#       Field Description                                            img  \
# 64019   NaN         NaN  /games/boxart/full_3574287AmericaFrontccc.jpg
# 64020   NaN         NaN                      /games/boxart/default.jpg
# 64021   NaN         NaN                      /games/boxart/default.jpg
# 64022   NaN         NaN                      /games/boxart/default.jpg
# 64023   NaN         NaN    /games/boxart/full_2129671JapanFrontccc.jpg
# 64024   NaN         NaN    /games/boxart/full_2294305JapanFrontccc.jpg
# 64025   NaN         NaN  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64026   NaN         NaN  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64027   NaN         NaN  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64028   NaN         NaN    /games/boxart/full_6012940JapanFrontccc.png
# 64029   NaN         NaN                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 64019           Witch on the Holy Night     PS4  Visual Novel
# 64020                    Without Within      PC  Visual Novel
# 64021                  Without Within 2      PC  Visual Novel
# 64022                  Without Within 3      PC  Visual Novel
# 64023                World End Syndrome     PSV  Visual Novel
# 64024                World End Syndrome     PS4  Visual Novel
# 64025             XBlaze Lost: Memories      PC  Visual Novel
# 64026                      Yoru, Tomosu     PS4  Visual Novel
# 64027                      Yoru, Tomosu      NS  Visual Novel
# 64028   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64029  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 64019             Type-Moon             Type-Moon           NaN          NaN
# 64020           InvertMouse           InvertMouse           NaN          NaN
# 64021           InvertMouse           InvertMouse           NaN          NaN
# 64022           InvertMouse           InvertMouse           NaN          NaN
# 64023      Arc System Works      Arc System Works           NaN          NaN
# 64024      Arc System Works      Arc System Works           NaN          NaN
# 64025           Aksys Games      Arc System Works           NaN          NaN
# 64026  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64027  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64028          Idea Factory               Otomate           NaN          NaN
# 64029               Unknown            G.rev Ltd.           NaN          NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date last_update
# 64019       NaN       NaN        NaN          NaN   2022-12-08  2023-07-05
# 64020       NaN       NaN        NaN          NaN   2015-01-22  2018-12-25
# 64021       NaN       NaN        NaN          NaN   2015-11-09  2018-12-25
# 64022       NaN       NaN        NaN          NaN   2018-05-03  2018-12-25
# 64023       NaN       NaN        NaN          NaN   2018-04-26  2019-04-03
# 64024       NaN       NaN        NaN          NaN   2018-04-26  2019-04-03
# 64025       NaN       NaN        NaN          NaN   2016-08-11  2019-01-28
# 64026       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64027       NaN       NaN        NaN          NaN   2020-07-30  2020-05-09
# 64028       NaN       NaN        NaN          NaN   2019-02-28  2019-02-24
# 64029       NaN       NaN        NaN          NaN          NaN  2023-09-29

# %%
df.shape
# Out:
# (64030, 16)

# %%
df.columns
# Out:
# Index(['Field', 'Description', 'img', 'title', 'console', 'genre', 'publisher',
#        'developer', 'critic_score', 'total_sales', 'na_sales', 'jp_sales',
#        'pal_sales', 'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Field            object
# Description      object
# img              object
# title            object
# console          object
# genre            object
# publisher        object
# developer        object
# critic_score    float64
# total_sales     float64
# na_sales        float64
# jp_sales        float64
# pal_sales       float64
# other_sales     float64
# release_date     object
# last_update      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64030 entries, 0 to 64029
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  object
#  13  last_update   17879 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 6.8+ MB

# %%
df.isnull().sum()
# Out:
# img                14
# title              14
# console            14
# genre              14
# publisher          14
# developer          31
# critic_score    57352
# total_sales     45108
# na_sales        51393
# jp_sales        57304
# pal_sales       51206
# other_sales     48902
# release_date     7065
# last_update     46151
# dtype: int64

# %%
# Handling Missing data:
df.fillna(df.mean(numeric_only = True), inplace = True)

# For categorial Values:
for col in df.select_dtypes(include=['object', 'category']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# img             0
# title           0
# console         0
# genre           0
# publisher       0
# developer       0
# critic_score    0
# total_sales     0
# na_sales        0
# jp_sales        0
# pal_sales       0
# other_sales     0
# release_date    0
# last_update     0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#                               img               title console  genre  \
# count                       64030               64030   64030  64030
# unique                      56177               39798      81     20
# top     /games/boxart/default.jpg  Plants vs. Zombies      PC   Misc
# freq                         7824                  31   12631   9318
# mean                          NaN                 NaN     NaN    NaN
# std                           NaN                 NaN     NaN    NaN
# min                           NaN                 NaN     NaN    NaN
# 25%                           NaN                 NaN     NaN    NaN
# 50%                           NaN                 NaN     NaN    NaN
# 75%                           NaN                 NaN     NaN    NaN
# max                           NaN                 NaN     NaN    NaN
#
#        publisher developer  critic_score   total_sales      na_sales  \
# count      64030     64030  64030.000000  64030.000000  64030.000000
# unique      3383      8862           NaN           NaN           NaN
# top      Unknown   Unknown           NaN           NaN           NaN
# freq        8856      4466           NaN           NaN           NaN
# mean         NaN       NaN      7.220440      0.349113      0.264740
# std          NaN       NaN      0.470524      0.438941      0.219803
# min          NaN       NaN      1.000000      0.000000      0.000000
# 25%          NaN       NaN      7.220440      0.349113      0.264740
# 50%          NaN       NaN      7.220440      0.349113      0.264740
# 75%          NaN       NaN      7.220440      0.349113      0.264740
# max          NaN       NaN     10.000000     20.320000      9.760000
#
#             jp_sales     pal_sales   other_sales release_date last_update
# count   64030.000000  64030.000000  64030.000000        64030       64030
# unique           NaN           NaN           NaN         7922        1545
# top              NaN           NaN           NaN   1994-01-01  2018-01-06
# freq             NaN           NaN           NaN         7580       46316
# mean        0.102281      0.149472      0.043041          NaN         NaN
# std         0.054709      0.175717      0.061556          NaN         NaN
# min         0.000000      0.000000      0.000000          NaN         NaN
# 25%         0.102281      0.149472      0.043041          NaN         NaN
# 50%         0.102281      0.149472      0.043041          NaN         NaN
# 75%         0.102281      0.149472      0.043041          NaN         NaN
# max         2.130000      9.850000      3.120000          NaN         NaN

# %% [markdown]
# # Handling Outliers:

# %%
Q1 = df['total_sales'].quantile(0.25)
Q3 = df['total_sales'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['total_sales'] >= lower_bound) & (df['total_sales'] <= upper_bound)].copy()

print('Number of outliers before:',len(df))
print('Number of outliers after:', len(df_outliers))
# Out:
# Number of outliers before: 64030
# Number of outliers after: 45108

# %% [markdown]
# # Univariate Analysis:

# %%
# Get a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Get a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Temporarily disable mathtext parsing for tick labels
plt.rcParams['text.usetex'] = False # Moved outside the loop to apply to all categorical plots

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    # Ensure the data in the column is treated as string to avoid issues with non-string types
    sns.countplot(data=df, x=df[col].astype(str))
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Select numerical columns for bivariate analysis:
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Perform bivariate analysis for numerical columns using scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Bivariate Analysis: {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Select categorical columns for bivariate analysis:
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Perform bivariate analysis for categorical columns using countplots
for i in range(len(categorical_cols)):
    for j in range(i + 1, len(categorical_cols)):
        col1 = categorical_cols[i]
        col2 = categorical_cols[j]
        plt.figure(figsize=(12, 8))
        sns.countplot(data=df, x=col1, hue=col2)
        plt.title(f'Bivariate Analysis: {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel('Count')
        plt.xticks(rotation=45, ha='right')
        plt.legend(title=col2)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Thank you
