# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/grammy_winner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("grammy_winners.csv")
df.head(11)
# Out:
#     year  annual_edition            category  \
# 0   2024              67   Album Of The Year
# 1   2024              67   Album Of The Year
# 2   2024              67  Record Of The Year
# 3   2024              67  Record Of The Year
# 4   2024              67  Record Of The Year
# 5   2024              67  Record Of The Year
# 6   2024              67   Album Of The Year
# 7   2024              67   Album Of The Year
# 8   2024              67   Album Of The Year
# 9   2024              67   Album Of The Year
# 10  2024              67   Album Of The Year
#
#                                                artist  \
# 0   Jack Antonoff, Aaron Dessner & Taylor Swift, p...
# 1                                             Beyoncé
# 2   Giles Martin & Paul McCartney, producers; Geof...
# 3   Beyoncé, Nate Ferraro, Killah B & Raphael Saad...
# 4   Julian Bunetta, producer; Julian Bunetta & Jef...
# 5   Cirkut & A. G. Cook, producers; Cirkut & Manny...
# 6   Jack Antonoff, Julian Bunetta, Ian Kirkpatrick...
# 7   Charli xcx, Cirkut & A. G. Cook, producers; A....
# 8   Jacob Collier, producer; Ben Bloomberg, Jacob ...
# 9   Billie Eilish & FINNEAS, producers; Thom Beeme...
# 10  Daniel Nigro, producer; Mitch McCarthy & Danie...
#
#                                         song_or_album  winner  \
# 0                       THE TORTURED POETS DEPARTMENT   False
# 1                                       COWBOY CARTER    True
# 2                                        Now And Then   False
# 3                                      TEXAS HOLD 'EM   False
# 4                                            Espresso   False
# 5                                                 360   False
# 6                                      Short n' Sweet   False
# 7                                                BRAT   False
# 8                                       Djesse Vol. 4   False
# 9                                HIT ME HARD AND SOFT   False
# 10  Chappell Roan The Rise And Fall Of A Midwest P...   False
#
#                                                   url
# 0   https://www.grammy.com/awards/67th-annual-gram...
# 1   https://www.grammy.com/awards/67th-annual-gram...
# 2   https://www.grammy.com/awards/67th-annual-gram...
# 3   https://www.grammy.com/awards/67th-annual-gram...
# 4   https://www.grammy.com/awards/67th-annual-gram...
# 5   https://www.grammy.com/awards/67th-annual-gram...
# 6   https://www.grammy.com/awards/67th-annual-gram...
# 7   https://www.grammy.com/awards/67th-annual-gram...
# 8   https://www.grammy.com/awards/67th-annual-gram...
# 9   https://www.grammy.com/awards/67th-annual-gram...
# 10  https://www.grammy.com/awards/67th-annual-gram...

# %%
df.tail(11)
# Out:
#        year  annual_edition                      category  \
# 25358  1958               1             Album Of The Year
# 25359  1958               1              Song Of The Year
# 25360  1958               1            Record Of The Year
# 25361  1958               1            Record Of The Year
# 25362  1958               1             Album Of The Year
# 25363  1958               1             Album Of The Year
# 25364  1958               1             Album Of The Year
# 25365  1958               1             Album Of The Year
# 25366  1958               1  Best Vocal Performance, Male
# 25367  1958               1  Best Vocal Performance, Male
# 25368  1958               1  Best Vocal Performance, Male
#
#                                   artist  \
# 25358                                NaN
# 25359  "Nel Blu Dipinto Di Blu (Volare)"
# 25360                                NaN
# 25361                                NaN
# 25362                      Henry Mancini
# 25363                                NaN
# 25364                                NaN
# 25365                                NaN
# 25366                         Perry Como
# 25367                                NaN
# 25368                                NaN
#
#                                            song_or_album  winner  \
# 25358                           Come Fly With Me (Album)   False
# 25359                    Nel Blu Dipinto Di Blu (Volare)    True
# 25360                                     Fever (Single)   False
# 25361                               Catch A Falling Star   False
# 25362                          The Music From Peter Gunn    True
# 25363  Tchaikovsky: Concerto No. 1, In B-Flat Minor, ...   False
# 25364                            Only The Lonely (Album)   False
# 25365  Ella Fitzgerald Sings The Irving Berlin Song B...   False
# 25366                               Catch A Falling Star    True
# 25367                                Witchcraft (Single)   False
# 25368           Nel Blu Dipinto Di Blu (Volare) (Single)   False
#
#                                                      url
# 25358  https://www.grammy.com/awards/1st-annual-gramm...
# 25359  https://www.grammy.com/awards/1st-annual-gramm...
# 25360  https://www.grammy.com/awards/1st-annual-gramm...
# 25361  https://www.grammy.com/awards/1st-annual-gramm...
# 25362  https://www.grammy.com/awards/1st-annual-gramm...
# 25363  https://www.grammy.com/awards/1st-annual-gramm...
# 25364  https://www.grammy.com/awards/1st-annual-gramm...
# 25365  https://www.grammy.com/awards/1st-annual-gramm...
# 25366  https://www.grammy.com/awards/1st-annual-gramm...
# 25367  https://www.grammy.com/awards/1st-annual-gramm...
# 25368  https://www.grammy.com/awards/1st-annual-gramm...

# %%
df.shape
# Out:
# (25369, 7)

# %%
df.columns
# Out:
# Index(['year', 'annual_edition', 'category', 'artist', 'song_or_album',
#        'winner', 'url'],
#       dtype='object')

# %%
df.dtypes
# Out:
# year               int64
# annual_edition     int64
# category          object
# artist            object
# song_or_album     object
# winner              bool
# url               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25369 entries, 0 to 25368
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            25369 non-null  int64
#  1   annual_edition  25369 non-null  int64
#  2   category        25369 non-null  object
#  3   artist          13190 non-null  object
#  4   song_or_album   25348 non-null  object
#  5   winner          25369 non-null  bool
#  6   url             25369 non-null  object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                year  annual_edition
# count  25369.000000    25369.000000
# mean    1995.791360       38.791360
# std       17.998934       17.998934
# min     1958.000000        1.000000
# 25%     1982.000000       25.000000
# 50%     1998.000000       41.000000
# 75%     2010.000000       53.000000
# max     2024.000000       67.000000

# %%
df.isnull().sum()
# Out:
# year              0
# annual_edition    0
# category          0
# winner            0
# url               0
# dtype: int64

# %%
df_cleaned = df.drop_duplicates()

# %%
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['song_or_album'])

# %%
# Convert year to numeric
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# Filter only winners
df_winners = df[df['winner'] == True]

# %%
# 1. Number of Awards by Year
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='year', color='royalblue', alpha=0.8)
plt.xticks(rotation=45)
plt.title("Number of Grammy Awards Given Each Year")
plt.xlabel("Year")
plt.ylabel("Number of Awards")
plt.show()

# %%
# 2. Most Awarded Categories
plt.figure(figsize=(12, 6))
categories = df_winners['category'].value_counts().head(10)
sns.barplot(x=categories.values, y=categories.index, palette='coolwarm')
plt.title("Top 10 Most Awarded Categories")
plt.xlabel("Number of Awards")
plt.ylabel("Category")
plt.show()

# %%
# Thank you
