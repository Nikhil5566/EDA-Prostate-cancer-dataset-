# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Indian_Accidents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('accident_prediction_india.csv')
df.head(11)
# Out:
#            State Name City Name  Year     Month Day of Week Time of Day  \
# 0   Jammu and Kashmir   Unknown  2021       May      Monday        1:46
# 1       Uttar Pradesh   Lucknow  2018   January   Wednesday       21:30
# 2        Chhattisgarh   Unknown  2023       May   Wednesday        5:37
# 3       Uttar Pradesh   Lucknow  2020      June    Saturday        0:31
# 4              Sikkim   Unknown  2021    August    Thursday       11:21
# 5           Meghalaya   Unknown  2020  November     Tuesday         8:4
# 6              Sikkim   Unknown  2021   October      Monday       18:55
# 7    Himachal Pradesh   Unknown  2022  December   Wednesday       11:40
# 8           Rajasthan   Jodhpur  2021      July    Saturday        8:26
# 9           Rajasthan   Jodhpur  2018    August    Saturday         2:1
# 10   Himachal Pradesh   Unknown  2020     April    Thursday       22:25
#
#    Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# ...

# %%
df.tail(11)
# Out:
#              State Name City Name  Year      Month Day of Week Time of Day  \
# 2989              Bihar   Unknown  2021      March    Saturday         3:0
# 2990          Meghalaya   Unknown  2020   December      Sunday        2:40
# 2991       Chhattisgarh   Unknown  2020  September      Friday        3:24
# 2992            Tripura   Unknown  2018   December     Tuesday       20:47
# 2993              Bihar   Unknown  2023     August   Wednesday         2:7
# 2994        Uttarakhand   Unknown  2021   February      Monday       10:47
# 2995         Tamil Nadu   Chennai  2021    January      Sunday        1:15
# 2996        Uttarakhand   Unknown  2018       July      Sunday       10:12
# 2997          Meghalaya   Unknown  2021    January    Thursday       19:34
# 2998          Meghalaya   Unknown  2023       June      Sunday       20:54
# 2999  Arunachal Pradesh   Unknown  2020  September      Monday        7:19
#
# ...

# %%
df.shape
# Out:
# (3000, 22)

# %%
df.columns
# Out:
# Index(['State Name', 'City Name', 'Year', 'Month', 'Day of Week',
#        'Time of Day', 'Accident Severity', 'Number of Vehicles Involved',
#        'Vehicle Type Involved', 'Number of Casualties', 'Number of Fatalities',
#        'Weather Conditions', 'Road Type', 'Road Condition',
#        'Lighting Conditions', 'Traffic Control Presence', 'Speed Limit (km/h)',
#        'Driver Age', 'Driver Gender', 'Driver License Status',
#        'Alcohol Involvement', 'Accident Location Details'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State Name                     object
# City Name                      object
# Year                            int64
# Month                          object
# Day of Week                    object
# Time of Day                    object
# Accident Severity              object
# Number of Vehicles Involved     int64
# Vehicle Type Involved          object
# Number of Casualties            int64
# Number of Fatalities            int64
# Weather Conditions             object
# Road Type                      object
# Road Condition                 object
# Lighting Conditions            object
# Traffic Control Presence       object
# Speed Limit (km/h)              int64
# Driver Age                      int64
# Driver Gender                  object
# Driver License Status          object
# Alcohol Involvement            object
# Accident Location Details      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State Name                   3000 non-null   object
#  1   City Name                    3000 non-null   object
#  2   Year                         3000 non-null   int64
#  3   Month                        3000 non-null   object
#  4   Day of Week                  3000 non-null   object
#  5   Time of Day                  3000 non-null   object
#  6   Accident Severity            3000 non-null   object
#  7   Number of Vehicles Involved  3000 non-null   int64
#  8   Vehicle Type Involved        3000 non-null   object
#  9   Number of Casualties         3000 non-null   int64
#  10  Number of Fatalities         3000 non-null   int64
#  11  Weather Conditions           3000 non-null   object
#  12  Road Type                    3000 non-null   object
# ...

# %%
df.describe()
# Out:
#               Year  Number of Vehicles Involved  Number of Casualties  \
# count  3000.000000                  3000.000000           3000.000000
# mean   2020.530000                     2.996000              5.066000
# std       1.683858                     1.428285              3.214097
# min    2018.000000                     1.000000              0.000000
# 25%    2019.000000                     2.000000              2.000000
# 50%    2021.000000                     3.000000              5.000000
# 75%    2022.000000                     4.000000              8.000000
# max    2023.000000                     5.000000             10.000000
#
#        Number of Fatalities  Speed Limit (km/h)  Driver Age
# count           3000.000000         3000.000000  3000.00000
# mean               2.455333           74.940667    44.17700
# std                1.717650           26.765088    15.40286
# min                0.000000           30.000000    18.00000
# ...

# %%
df.isnull().sum()
# Out:
# State Name                       0
# City Name                        0
# Year                             0
# Month                            0
# Day of Week                      0
# Time of Day                      0
# Accident Severity                0
# Number of Vehicles Involved      0
# Vehicle Type Involved            0
# Number of Casualties             0
# Number of Fatalities             0
# Weather Conditions               0
# Road Type                        0
# Road Condition                   0
# Lighting Conditions              0
# Traffic Control Presence       716
# Speed Limit (km/h)               0
# Driver Age                       0
# Driver Gender                    0
# Driver License Status          975
# Alcohol Involvement              0
# Accident Location Details        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State Name                     0
# City Name                      0
# Year                           0
# Month                          0
# Day of Week                    0
# Time of Day                    0
# Accident Severity              0
# Number of Vehicles Involved    0
# Vehicle Type Involved          0
# Number of Casualties           0
# Number of Fatalities           0
# Weather Conditions             0
# Road Type                      0
# Road Condition                 0
# Lighting Conditions            0
# Traffic Control Presence       0
# Speed Limit (km/h)             0
# Driver Age                     0
# Driver Gender                  0
# Driver License Status          0
# Alcohol Involvement            0
# Accident Location Details      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Vehicle Type Involved', data=df, palette='viridis')
plt.title('Vehicle Type Involved Distribution (0 = Not Churned, 1 = Churned)')
plt.xlabel('Vehicle Type Involved')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.histplot(df['Driver Age'], bins=30, kde=True, color='blue')
plt.title('Driver Age Distribution of Customers')
plt.xlabel('Driver Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(y=df['Year'], color='green')
plt.title('Boxplot of Year')
plt.ylabel('Year')
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
# Thank you
