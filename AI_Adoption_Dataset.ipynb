# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/AI_Adoption_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('ai_adoption_dataset.csv')
df.head(11)
# Out:
#       country        industry           ai_tool  adoption_rate  \
# 0         USA      Technology           ChatGPT          40.45
# 1      France   Manufacturing        Midjourney          35.72
# 2   Australia  Transportation           ChatGPT          13.47
# 3          UK   Manufacturing           ChatGPT          48.46
# 4          UK     Agriculture  Stable Diffusion          34.06
# 5      Brazil       Education        Midjourney          64.54
# 6         USA      Healthcare              Bard          81.83
# 7   Australia       Education           ChatGPT          20.85
# 8       China          Retail        Midjourney          39.90
# 9         USA     Agriculture        Midjourney          20.53
# 10     Canada       Education        Midjourney          24.10
#
#     daily_active_users  year  \
# 0                 2461  2023
# 1                 8496  2024
# 2                 8641  2024
# 3                 3488  2023
# 4                 1124  2024
# 5                 3267  2024
# 6                 4265  2023
# 7                 5940  2023
# 8                  613  2024
# 9                 8310  2023
# 10                7182  2024
#
#                                         user_feedback age_group company_size
# 0   YyvLXOFyevRMSvJtkXodLvgejiqQNvSOZfeeJASDOVTxwm...     35-44      Startup
# 1   AdFVhenjthYSKJNzxzfaGQk wLnjRCgrHTyfXQEFjFJCMO...     18-24   Enterprise
# 2   zgNPmXBICRNbpjpTqIUWmMTeTYsInDNtAmzuxpDvcUZEAi...     45-54      Startup
# 3   LxeKzQFbPvhxXUSgPVlLLJ pUFaicjCgiMtAmsTjovkrdE...     45-54   Enterprise
# 4   IOQtQoSKdSmiXRsUKpjXjXZgQohymFkVUvOASXlEnVsIOS...     45-54          SME
# 5   PDkHPYQGOo XqLNwpEsZlbubUVBUDBujoPCWEDoCtcwzKX...       55+      Startup
# 6   VXo RcPqLBqywVUcwrpjmTha FxLtebijbOiZMEIYqkLEK...     35-44   Enterprise
# 7   MCVWNxfkdvijPwFleHKDKJTIexXAzweDWyBGDQVcOrfAsn...     25-34   Enterprise
# 8    JJyYjvZPWunxapLpTfaampdgLFquyzjJELCEQfNnZLtXn...       55+          SME
# 9   BmKCEuMhGTktndFlwMDIq UVbeFeqlnYXmRypfMgBwuG c...     35-44      Startup
# 10  YdwlGHwJUqyHYwWldqeIPPGBUujdNGwDJJqrupkIPFnZHA...       55+      Startup

# %%
df.tail(11)
# Out:
#             country        industry           ai_tool  adoption_rate  \
# 144989    Australia   Manufacturing        Midjourney          87.38
# 144990          USA      Technology  Stable Diffusion          30.58
# 144991  South Korea       Education        Midjourney          16.51
# 144992           UK  Transportation        Midjourney          98.94
# 144993      Germany          Retail  Stable Diffusion          85.08
# 144994      Germany          Retail        Midjourney          88.81
# 144995    Australia     Agriculture        Midjourney          86.93
# 144996      Germany       Education        Midjourney          51.99
# 144997          USA         Finance  Stable Diffusion          47.35
# 144998          USA          Retail           ChatGPT          31.87
# 144999       Canada      Technology            Claude          96.84
#
#         daily_active_users  year  \
# 144989                7249  2024
# 144990                8297  2024
# 144991                 130  2024
# 144992                4373  2024
# 144993                4221  2024
# 144994                8910  2024
# 144995                7921  2023
# 144996                6301  2024
# 144997                4726  2023
# 144998                2481  2024
# 144999                6479  2024
#
#                                             user_feedback age_group  \
# 144989  DtlxQdJimAPwpHWITHBONcDjGTjArtsJgeDN YgGswswFN...     45-54
# 144990  nkATfOEMvPzqTMKvSkGFrPRDVnpMsLTM APzaNysPetNik...     18-24
# 144991  PnjJnr dRqzEFLRbkHzKIEMA JySivgXbRoQifZbfOqkXz...     25-34
# 144992  INObQzmd RgDtsZUlViYAYdhpvRDAUXouympYlNsbCCkCe...     25-34
# 144993  HLPtcjnPARVGqeBtZdQbtjSGgnVDdGFhrUkSMzDyXybEwb...     35-44
# 144994  GBQgYYRvWTqZMftupnt cZ XNROkgHaeXjFdMCmYStKiBa...     25-34
# 144995  PxWkyTVwSNPoTXjsKzjbAFEfyJ MdgY CXjvSrkkHOTGcb...     18-24
# 144996  PtOmfGyWyZueDERRioCvbNgXomcpNNLFUjRuMEqeMrqR L...     45-54
# 144997  VQuOdOKjRhchmEFrzvGlqsGOc fbTXzuzQzswt pZTCmhx...     45-54
# 144998  IRFOudTsoPrlrKypvToOx llYkLoLqrw  EMHOtyAKmqXq...     25-34
# 144999  pwVBio hjlquPxOkabYZsvNwXFWresQdMGmeqmBicAbHzo...     35-44
#
#        company_size
# 144989          SME
# 144990   Enterprise
# 144991          SME
# 144992   Enterprise
# 144993      Startup
# 144994   Enterprise
# 144995          SME
# 144996          SME
# 144997      Startup
# 144998   Enterprise
# 144999   Enterprise

# %%
df.shape
# Out:
# (145000, 9)

# %%
df.columns
# Out:
# Index(['country', 'industry', 'ai_tool', 'adoption_rate', 'daily_active_users',
#        'year', 'user_feedback', 'age_group', 'company_size'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                object
# industry               object
# ai_tool                object
# adoption_rate         float64
# daily_active_users      int64
# year                    int64
# user_feedback          object
# age_group              object
# company_size           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145000 entries, 0 to 144999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   country             145000 non-null  object
#  1   industry            145000 non-null  object
#  2   ai_tool             145000 non-null  object
#  3   adoption_rate       145000 non-null  float64
#  4   daily_active_users  145000 non-null  int64
#  5   year                145000 non-null  int64
#  6   user_feedback       145000 non-null  object
#  7   age_group           145000 non-null  object
#  8   company_size        145000 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 10.0+ MB

# %%
df.isnull().sum()
# Out:
# country               0
# industry              0
# ai_tool               0
# adoption_rate         0
# daily_active_users    0
# year                  0
# user_feedback         0
# age_group             0
# company_size          0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#           country       industry  ai_tool  adoption_rate  daily_active_users  \
# count      145000         145000   145000  145000.000000       145000.000000
# unique         10              8        5            NaN                 NaN
# top     Australia  Manufacturing  ChatGPT            NaN                 NaN
# freq        14723          18267    58045            NaN                 NaN
# mean          NaN            NaN      NaN      49.873025         5039.302683
# std           NaN            NaN      NaN      28.842523         2858.124918
# min           NaN            NaN      NaN       0.000000          100.000000
# 25%           NaN            NaN      NaN      24.930000         2566.000000
# 50%           NaN            NaN      NaN      49.760000         5036.000000
# 75%           NaN            NaN      NaN      74.840000         7515.000000
# max           NaN            NaN      NaN     100.000000         9999.000000
#
#                  year                                      user_feedback  \
# count   145000.000000                                             145000
# unique            NaN                                             145000
# top               NaN  pwVBio hjlquPxOkabYZsvNwXFWresQdMGmeqmBicAbHzo...
# freq              NaN                                                  1
# mean      2023.703117                                                NaN
# std          0.456886                                                NaN
# min       2023.000000                                                NaN
# 25%       2023.000000                                                NaN
# 50%       2024.000000                                                NaN
# 75%       2024.000000                                                NaN
# max       2024.000000                                                NaN
#
#        age_group company_size
# count     145000       145000
# unique         5            3
# top          55+      Startup
# freq       29424        48601
# mean         NaN          NaN
# std          NaN          NaN
# min          NaN          NaN
# 25%          NaN          NaN
# 50%          NaN          NaN
# 75%          NaN          NaN
# max          NaN          NaN

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling Outliers

# %%
Q1 = df['daily_active_users'].quantile(0.25)
Q3 = df['daily_active_users'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['daily_active_users'] >= lower_bound) & (df['daily_active_users'] <= upper_bound)].copy()

print("Number of rows after removing outliers:", len(df))
print("Number of rows removed:", len(df_outliers))
# Out:
# Number of rows after removing outliers: 145000
# Number of rows removed: 145000

# %% [markdown]
# # Univariate Analysis

# %%
# Get a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Get a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Temporarily disable mathtext parsing for tick labels
plt.rcParams['text.usetex'] = False # Moved outside the loop to apply to all categorical plots

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    # Ensure the data in the column is treated as string to avoid issues with non-string types
    sns.countplot(data=df, x=df[col].astype(str))
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Select numerical columns for bivariate analysis:
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Perform bivariate analysis for numerical columns using scatter plots
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        col1 = numerical_cols[i]
        col2 = numerical_cols[j]
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x=col1, y=col2)
        plt.title(f'Bivariate Analysis: {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# Select categorical columns for bivariate analysis:
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Perform bivariate analysis for categorical columns using countplots
for i in range(len(categorical_cols)):
    for j in range(i + 1, len(categorical_cols)):
        col1 = categorical_cols[i]
        col2 = categorical_cols[j]
        plt.figure(figsize=(12, 8))
        sns.countplot(data=df, x=col1, hue=col2)
        plt.title(f'Bivariate Analysis: {col1} vs {col2}')
        plt.xlabel(col1)
        plt.ylabel('Count')
        plt.xticks(rotation=45, ha='right')
        plt.legend(title=col2)
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
