# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Amazon_Products_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Amazon-Products.csv')
df.head(11)
# Out:
#     Unnamed: 0                                               name  \
# 0            0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1            1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2            2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3            3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4            4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
# 5            5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...
# 6            6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...
# 7            7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...
# 8            8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...
# 9            9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...
# 10          10  Daikin 1 Ton 3 Star Inverter Split AC (Copper,...
#
#    main_category      sub_category  \
# 0     appliances  Air Conditioners
# 1     appliances  Air Conditioners
# 2     appliances  Air Conditioners
# ...

# %%
df.tail(11)
# Out:
#         Unnamed: 0                                               name  \
# 551574        1093  Just rider Arm Sleeves UV Protection for Drivi...
# 551575        1094       Just Rider Compression Clothing (XXL, Black)
# 551576        1095  PANCHTATAVA Yoga Mat Cover with Adjustable Sho...
# 551577        1096  Obsessions Reversible Printed Yoga Mat,Anti-Sl...
# 551578        1097                              Puma Women Sweatshirt
# 551579        1098  BE SAVAGE Pink I Purple You Hoodie Suitable fo...
# 551580        1099                Adidas Regular Fit Men's Track Tops
# 551581        1100          Redwolf Noice Toit Smort - Hoodie (Black)
# 551582        1101     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)
# 551583        1102                                    Puma Men Shorts
# 551584        1103  Mothercare Printed Cotton Elastane Girls Infan...
#
#            main_category sub_category  \
# 551574  sports & fitness         Yoga
# 551575  sports & fitness         Yoga
# ...

# %%
df.shape
# Out:
# (551585, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'main_category', 'sub_category', 'image', 'link',
#        'ratings', 'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# name              object
# main_category     object
# sub_category      object
# image             object
# link              object
# ratings           object
# no_of_ratings     object
# discount_price    object
# actual_price      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551585 entries, 0 to 551584
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      551585 non-null  int64
#  1   name            551585 non-null  object
#  2   main_category   551585 non-null  object
#  3   sub_category    551585 non-null  object
#  4   image           551585 non-null  object
#  5   link            551585 non-null  object
#  6   ratings         375791 non-null  object
#  7   no_of_ratings   375791 non-null  object
#  8   discount_price  490422 non-null  object
#  9   actual_price    533772 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 42.1+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# name                   0
# main_category          0
# sub_category           0
# image                  0
# link                   0
# ratings           175794
# no_of_ratings     175794
# discount_price     61163
# actual_price       17813
# dtype: int64

# %%
df['ratings'] = df['ratings'].fillna(df['ratings'].mode()[0])
df['no_of_ratings'] = df['no_of_ratings'].fillna(df['no_of_ratings'].mode()[0])
df['discount_price'] = df['discount_price'].fillna(df['discount_price'].mode()[0])
df['actual_price'] = df['actual_price'].fillna(df['actual_price'].mode()[0])
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551585 entries, 0 to 551584
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      551585 non-null  int64
#  1   name            551585 non-null  object
#  2   main_category   551585 non-null  object
#  3   sub_category    551585 non-null  object
#  4   image           551585 non-null  object
#  5   link            551585 non-null  object
#  6   ratings         551585 non-null  object
#  7   no_of_ratings   551585 non-null  object
#  8   discount_price  551585 non-null  object
#  9   actual_price    551585 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 42.1+ MB
# Unnamed: 0        0
# name              0
# main_category     0
# sub_category      0
# image             0
# link              0
# ratings           0
# no_of_ratings     0
# discount_price    0
# actual_price      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling Outliers

# %%
# !pip install --upgrade pandas

# %%
# Changing discount_price to numeric value:
df['discount_price'] = df['discount_price'].str.replace('₹', '',regex = False).str.replace(',','', regex = False)
df['discount_price'] = pd.to_numeric(df['discount_price'])

# Example using IQR to identify and remove outliers for the 'discount_price' column
Q1 = df['discount_price'].quantile(0.25)
Q3 = df['discount_price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_cleaned = df[(df['discount_price'] >= lower_bound) & (df['discount_price'] <= upper_bound)]

print(f"Original shape: {df.shape}")
print(f"Shape after removing outliers: {df_cleaned.shape}")
# Out:
# Original shape: (551585, 10)
# Shape after removing outliers: (483056, 10)

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x = df['discount_price'])
plt.xlabel('Discount Price')
plt.title('Box Plot of Discount Price with Outiers')
plt.show()

# %% [markdown]
# # Univariant Analysis

# %%
df['discount_price'].value_counts(normalize = True)
# Out:
# discount_price
# ₹499       0.143969
# ₹299       0.027805
# ₹399       0.026306
# ₹999       0.023568
# ₹599       0.021320
#              ...
# ₹38,239    0.000002
# ₹23,565    0.000002
# ₹46,070    0.000002
# ₹42,043    0.000002
# ₹30,809    0.000002
# Name: proportion, Length: 27511, dtype: float64

# %%
# Histograms: For numerical variables
plt.figure(figsize = (15, 8))
plt.hist(df['discount_price'], bins=20)
plt.xlabel('discount_price')
plt.ylabel('Frequency')
plt.title('Distribution of Your Numerical Column')
plt.show()

# %%
# Box plots:

plt.figure(figsize = (15, 8))
sns.boxplot(x=df['Unnamed: 0'])
plt.xlabel('Unnamed: 0')
plt.title('Box Plot of Your Numerical Column')
plt.show()

# %%
# Count plots:

plt.figure(figsize = (15, 8))
sns.countplot(x=df['main_category'])
plt.xlabel('main_category')
plt.ylabel('Count')
plt.title('Count of Your Categorical Column')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels if they overlap
plt.show()

# %%
# Summarize the 'ratings' column
print(df['ratings'].describe())

# Visualize the distribution with a histogram
plt.figure(figsize = (15, 8))
plt.hist(df['ratings'], bins=20)
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')
plt.show()

# Visualize the distribution with a box plot
plt.figure(figsize = (15, 8))
sns.boxplot(x=df['ratings'])
plt.xlabel('Ratings')
plt.title('Box Plot of Ratings')
plt.show()
# Out:
# count     551585
# unique        49
# top          4.0
# freq      212403
# Name: ratings, dtype: object

# %% [markdown]
# # Bivariate Analysis

# %%
# Example: Numerical vs. Numerical (e.g., 'discount_price' and 'no_of_ratings')
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['discount_price'], df['no_of_ratings'])
plt.xlabel('Discount Price')
plt.ylabel('Number of Ratings')
plt.title('Scatter Plot of Discount Price vs. Number of Ratings')
plt.show()

# %%
# Example: Categorical vs. Numerical (e.g., 'main_category' and 'ratings')
# Box plot
plt.figure(figsize=(15, 8))
sns.boxplot(x='main_category', y='ratings', data=df)
plt.xlabel('Main Category')
plt.ylabel('Ratings')
plt.title('Box Plot of Ratings by Main Category')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Violin plot
plt.figure(figsize=(15, 8))
sns.violinplot(x='main_category', y='ratings', data=df)
plt.xlabel('Main Category')
plt.ylabel('Ratings')
plt.title('Violin Plot of Ratings by Main Category')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Example: Categorical vs. Categorical (e.g., 'main_category' and another categorical column if available)
# Assuming you have another categorical column, replace 'another_categorical_column'
# Count plot with hue
sns.countplot(x='main_category', hue='sub_category', data=df)
plt.xlabel('Main Category')
plt.ylabel('Count')
plt.title('Count of Main Category Grouped by Another Categorical Column')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='ratings', bins=20, kde=True) # kde=True adds a kernel density estimate curve
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Product Ratings')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='main_category', order=df['main_category'].value_counts().index)
plt.xlabel('Main Category')
plt.ylabel('Count')
plt.title('Number of Products per Main Category')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='discount_price', y='no_of_ratings', alpha=0.5) # alpha for transparency
plt.xlabel('Discount Price')
plt.ylabel('Number of Ratings')
plt.title('Discount Price vs. Number of Ratings')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df, x='main_category', y='ratings')
plt.xlabel('Main Category')
plt.ylabel('Ratings')
plt.title('Ratings Distribution by Main Category')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
