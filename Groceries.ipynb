# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Groceries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('membership_groceries_userprofile.csv')
df.head(11)
# Out:
#     id  gender  shared_account membership_tier  membership_auto_renew  \
# 0    1    Male               0        standard                      1
# 1    2  Female               0        standard                      0
# 2    3  Female               0        standard                      0
# 3    4    Male               0        standard                      1
# 4    5  Female               1         premium                      1
# 5    6  Female               1         premium                      1
# 6    7  Female               1        standard                      0
# 7    8    Male               0         premium                      1
# 8    9  Female               0        standard                      1
# 9   10  Female               0         premium                      1
# 10  11    Male               1         premium                      0
#
#     membership_fee membership_start_date  push_notification_enabled  have_app  \
# ...

# %%
df.tail(11)
# Out:
#       id  gender  shared_account membership_tier  membership_auto_renew  \
# 847  848  Female               0        standard                      1
# 848  849    Male               0         premium                      1
# 849  850    Male               0         premium                      1
# 850  851    Male               1         premium                      1
# 851  852  Female               0         premium                      1
# 852  853  Female               0         premium                      1
# 853  854  Female               0        standard                      1
# 854  855  Female               0        standard                      1
# 855  856    Male               1        standard                      1
# 856  857  Female               1         premium                      1
# 857  858    Male               0        standard                      1
#
#      membership_fee membership_start_date  push_notification_enabled  \
# ...

# %%
df.shape
# Out:
# (858, 15)

# %%
df.columns
# Out:
# Index(['id', 'gender', 'shared_account', 'membership_tier',
#        'membership_auto_renew', 'membership_fee', 'membership_start_date',
#        'push_notification_enabled', 'have_app', 'app_engagement_score',
#        'bought_store_brand', 'promotion_participation_count',
#        'average_basket_size', 'use_count', 'reward_points_used'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                 int64
# gender                            object
# shared_account                     int64
# membership_tier                   object
# membership_auto_renew              int64
# membership_fee                     int64
# membership_start_date             object
# push_notification_enabled          int64
# have_app                           int64
# app_engagement_score             float64
# bought_store_brand                 int64
# promotion_participation_count      int64
# average_basket_size              float64
# use_count                          int64
# reward_points_used                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             858 non-null    int64
#  1   gender                         858 non-null    object
#  2   shared_account                 858 non-null    int64
#  3   membership_tier                858 non-null    object
#  4   membership_auto_renew          858 non-null    int64
#  5   membership_fee                 858 non-null    int64
#  6   membership_start_date          858 non-null    object
#  7   push_notification_enabled      858 non-null    int64
#  8   have_app                       858 non-null    int64
#  9   app_engagement_score           858 non-null    float64
#  10  bought_store_brand             858 non-null    int64
#  11  promotion_participation_count  858 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# id                               0
# gender                           0
# shared_account                   0
# membership_tier                  0
# membership_auto_renew            0
# membership_fee                   0
# membership_start_date            0
# push_notification_enabled        0
# have_app                         0
# app_engagement_score             0
# bought_store_brand               0
# promotion_participation_count    0
# average_basket_size              0
# use_count                        0
# reward_points_used               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

df[numeric_cols].hist(figsize=(14,12), bins=30)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df.groupby('gender')['membership_auto_renew'].mean().reset_index(),
            x='membership_auto_renew', y='gender')
plt.title("Membership renew ")
# Out:
# Text(0.5, 1.0, 'Membership renew ')

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
# Thank you
