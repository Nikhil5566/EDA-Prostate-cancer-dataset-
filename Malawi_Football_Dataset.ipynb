# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Malawi_Football_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Dataset_Malawi_National_Football_Team_Matches.csv')
df.head(11)
# Out:
#           Date           Opponent  Team Score  Opponent Score Result    Venue  \
# 0        ~1957  Northern Rhodesia         0.0             5.0   Loss  Unknown
# 1        ~1962              Ghana         0.0            12.0   Loss  Unknown
# 2        ~1968           Botswana         8.0             1.0    Win  Unknown
# 3   02/06/1996       South Africa         0.0             3.0   Loss     Away
# 4   07/07/1996             Zambia         1.0             1.0   Draw     Home
# 5   08/01/2010            Algeria         0.0             3.0   Loss     Away
# 6   11/01/2010             Angola         0.0             2.0   Loss     Away
# 7   14/01/2010               Mali         1.0             3.0   Loss     Away
# 8   04/09/2010            Tunisia         2.0             2.0   Draw     Away
# 9   09/10/2010               Chad         6.0             2.0    Win     Home
# 10  17/11/2010             Rwanda         2.0             1.0    Win     Home
#
# ...

# %%
df.tail(11)
# Out:
#           Date      Opponent  Team Score  Opponent Score Result Venue  \
# 62  23/03/2024       Senegal         0.0             1.0   Loss  Away
# 63  26/03/2024         Kenya         0.0             4.0   Loss  Home
# 64  06/06/2024      Sao Tome         3.0             1.0    Win  Home
# 65  10/06/2024    Eq. Guinea         0.0             1.0   Loss  Away
# 66  10/09/2024  Burkina Faso         3.0             0.0    Win  Home
# 67  11/10/2024       Senegal         0.0             4.0   Loss  Away
# 68  14/11/2024       Burundi         0.0             0.0   Draw  Home
# 69  18/11/2024  Burkina Faso         0.0             1.0   Loss  Away
# 70  02/03/2025       Comoros         2.0             0.0    Win  Away
# 71  20/03/2025       Namibia         0.0             1.0   Loss  Away
# 72  24/03/2025       Tunisia         NaN             NaN    TBD  Away
#
#                 Competition
# 62                 Friendly
# 63  Four Nations Tournament
# 64      World Cup Qualifier
# ...

# %%
df.shape
# Out:
# (73, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Opponent', 'Team Score', 'Opponent Score', 'Result', 'Venue',
#        'Competition'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date               object
# Opponent           object
# Team Score        float64
# Opponent Score    float64
# Result             object
# Venue              object
# Competition        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            73 non-null     object
#  1   Opponent        73 non-null     object
#  2   Team Score      72 non-null     float64
#  3   Opponent Score  72 non-null     float64
#  4   Result          73 non-null     object
#  5   Venue           73 non-null     object
#  6   Competition     73 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.1+ KB

# %%
df.describe(include = 'all')
# Out:
#          Date    Opponent  Team Score  Opponent Score Result Venue  \
# count      73          73   72.000000       72.000000     73    73
# unique     73          36         NaN             NaN      4     3
# top     ~1957  Mozambique         NaN             NaN   Loss  Away
# freq        1           6         NaN             NaN     35    40
# mean      NaN         NaN    0.833333        1.569444    NaN   NaN
# std       NaN         NaN    1.342690        1.758892    NaN   NaN
# min       NaN         NaN    0.000000        0.000000    NaN   NaN
# 25%       NaN         NaN    0.000000        0.000000    NaN   NaN
# 50%       NaN         NaN    0.000000        1.000000    NaN   NaN
# 75%       NaN         NaN    1.000000        2.000000    NaN   NaN
# max       NaN         NaN    8.000000       12.000000    NaN   NaN
#
#                 Competition
# count                    73
# unique                   12
# top     World Cup Qualifier
# freq                     19
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# Opponent          0
# Team Score        1
# Opponent Score    1
# Result            0
# Venue             0
# Competition       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
# Exploring the dataset through visualizations

## Distribution of Scores
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['Team Score'], kde=True, color='blue')
plt.title('Distribution of Team Scores')

plt.subplot(1, 2, 2)
sns.histplot(df['Opponent Score'], kde=True, color='red')
plt.title('Distribution of Opponent Scores')

plt.tight_layout()
plt.show()

# %%
## Count Plot of Match Results
plt.figure(figsize=(8, 6))
sns.countplot(x='Result', data=df, palette='viridis')
plt.title('Count of Match Results')
plt.show()

# %%
## Count Plot for Venue
plt.figure(figsize=(10, 6))
sns.countplot(x='Venue', data=df, palette='magma')
plt.title('Count of Matches by Venue')
plt.xticks(rotation=45)
plt.show()

# %%
## Pie Chart (using countplot style) for Competition distribution
plt.figure(figsize=(10, 6))
competition_counts = df['Competition'].value_counts()
sns.barplot(x=competition_counts.index, y=competition_counts.values, palette='coolwarm')
plt.title('Matches by Competition')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
# Thank you
