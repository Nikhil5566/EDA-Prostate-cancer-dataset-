# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Retail_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Retail_Prices_of _Products.csv')
df.head(11)
# Out:
#     Year    Month         GEO Product Category  \
# 0   2017  January  Province 1   Meat & Poultry
# 1   2017  January  Province 1   Meat & Poultry
# 2   2017  January  Province 1   Meat & Poultry
# 3   2017  January  Province 1   Meat & Poultry
# 4   2017  January  Province 1   Meat & Poultry
# 5   2017  January  Province 1   Meat & Poultry
# 6   2017  January  Province 1   Meat & Poultry
# 7   2017  January  Province 1   Meat & Poultry
# 8   2017  January  Province 1   Meat & Poultry
# 9   2017  January  Province 1   Meat & Poultry
# 10  2017  January  Province 1   Meat & Poultry
#
#                                Products  VALUE Taxable  Total tax rate  \
# 0       Beef stewing cuts, per kilogram  12.66      No            11.0
# 1     Beef striploin cuts, per kilogram  21.94      No            11.0
# 2   Beef top sirloin cuts, per kilogram  13.44      No            11.0
# 3           Beef rib cuts, per kilogram  20.17      No            11.0
# ...

# %%
df.tail(11)
# Out:
#         Year     Month          GEO       Product Category  \
# 118471  2025  February  Province 11    Legumes & Dry Goods
# 118472  2025  February  Province 11  Canned & Jarred Goods
# 118473  2025  February  Province 11        Grains & Bakery
# 118474  2025  February  Province 11  Canned & Jarred Goods
# 118475  2025  February  Province 11          Nuts & Snacks
# 118476  2025  February  Province 11          Nuts & Snacks
# 118477  2025  February  Province 11          Nuts & Snacks
# 118478  2025  February  Province 11  Toiletries & Cleaning
# 118479  2025  February  Province 11  Toiletries & Cleaning
# 118480  2025  February  Province 11  Toiletries & Cleaning
# 118481  2025  February  Province 11  Toiletries & Cleaning
#
#                                Products  VALUE Taxable  Total tax rate  \
# 118471                Hummus, 227 grams   3.82      No            12.0
# 118472           Salsa, 418 millilitres   4.53     Yes            12.0
# ...

# %%
df.shape
# Out:
# (118482, 12)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'GEO', 'Product Category', 'Products', 'VALUE',
#        'Taxable', 'Total tax rate', 'Value after tax', 'Essential',
#        'COORDINATE', 'UOM'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                  int64
# Month                object
# GEO                  object
# Product Category     object
# Products             object
# VALUE               float64
# Taxable              object
# Total tax rate      float64
# Value after tax     float64
# Essential            object
# COORDINATE          float64
# UOM                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118482 entries, 0 to 118481
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Year              118482 non-null  int64
#  1   Month             118482 non-null  object
#  2   GEO               118482 non-null  object
#  3   Product Category  118482 non-null  object
#  4   Products          118482 non-null  object
#  5   VALUE             118482 non-null  float64
#  6   Taxable           118482 non-null  object
#  7   Total tax rate    118482 non-null  float64
#  8   Value after tax   118482 non-null  float64
#  9   Essential         118482 non-null  object
#  10  COORDINATE        118482 non-null  float64
#  11  UOM               118482 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 10.8+ MB

# %%
df.describe()
# Out:
#                 Year          VALUE  Total tax rate  Value after tax  \
# count  118482.000000  118482.000000   118482.000000    118482.000000
# mean     2020.591837       5.437324       12.632134         5.515499
# std         2.355363       5.192748        2.899124         5.215311
# min      2017.000000       0.300000        5.000000         0.300000
# 25%      2019.000000       2.850000       11.000000         2.910000
# 50%      2021.000000       3.990000       13.000000         4.050000
# 75%      2023.000000       5.810000       15.000000         5.947500
# max      2025.000000      48.450000       15.000000        48.450000
#
#           COORDINATE
# count  118482.000000
# mean        6.501741
# std         3.172173
# min         1.100000
# 25%         3.750000
# 50%         6.500000
# 75%         9.240000
# max        11.990000

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# GEO                 0
# Product Category    0
# Products            0
# VALUE               0
# Taxable             0
# Total tax rate      0
# Value after tax     0
# Essential           0
# COORDINATE          0
# UOM                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
# 1. Regional Price Comparison
plt.figure(figsize=(12, 6))
region_avg = df.groupby('GEO')['VALUE'].mean().sort_values(ascending=False)
sns.barplot(x=region_avg.index, y=region_avg.values)
plt.title('Average Price by Region')
plt.ylabel('Average VALUE')
plt.xlabel('Region (GEO)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# 2. Tax Rate Distribution by Product Category
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Product Category', y='Total tax rate')
plt.title('Tax Rate Distribution by Product Category')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# 3. Taxable Products Count
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Taxable')
plt.title('Taxable vs Non-Taxable Product Count')
plt.tight_layout()
plt.show()

# %%
# 4. Heatmap

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
# Thank you
