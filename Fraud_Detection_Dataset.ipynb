# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Prostate-cancer-dataset-/blob/main/Fraud_Detection_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Fraud Detection Dataset.csv')
df.head(10)
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
# 5             T6     2095             2372.04   ATM Withdrawal
# 6             T7     4772              544.81     Bill Payment
# 7             T8     4092              635.75   ATM Withdrawal
# 8             T9     2638             2318.87    Bank Transfer
# 9            T10     3169             3656.17     Bill Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# ...

# %%
df.tail(10)
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 50990         T12629     1157             2898.06  Online Purchase
# 50991         T28348     1530             1069.09   ATM Withdrawal
# 50992         T43512     1584             3631.26    Bank Transfer
# 50993          T5873     4911             3613.59  Online Purchase
# 50994         T48244     4842             1587.84      POS Payment
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 50990                  8.0     Desktop  San Francisco
# 50991                  6.0      Tablet        Houston
# 50992                 17.0     Desktop        Seattle
# ...

# %%
df.shape
# Out:
# (51000, 12)

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'User_ID', 'Transaction_Amount', 'Transaction_Type',
#        'Time_of_Transaction', 'Device_Used', 'Location',
#        'Previous_Fraudulent_Transactions', 'Account_Age',
#        'Number_of_Transactions_Last_24H', 'Payment_Method', 'Fraudulent'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               48448 non-null  float64
#  5   Device_Used                       48527 non-null  object
#  6   Location                          48453 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    48531 non-null  object
# ...

# %%
df.describe()
# Out:
#             User_ID  Transaction_Amount  Time_of_Transaction  \
# count  51000.000000        48480.000000         48448.000000
# mean    3005.110176         2996.249784            11.488400
# std     1153.121107         5043.932555             6.922954
# min     1000.000000            5.030000             0.000000
# 25%     2007.000000         1270.552500             5.000000
# 50%     2996.000000         2524.100000            12.000000
# 75%     4006.000000         3787.240000            17.000000
# max     4999.000000        49997.800000            23.000000
#
#        Previous_Fraudulent_Transactions   Account_Age  \
# count                      51000.000000  51000.000000
# mean                           1.995725     60.033902
# std                            1.415150     34.384131
# min                            0.000000      1.000000
# 25%                            1.000000     30.000000
# 50%                            2.000000     60.000000
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                         2473
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %%
missing_values_cleaned = df_cleaned.isnull().sum()
missing_values_cleaned
# Out:
# Transaction_ID                      0
# User_ID                             0
# Transaction_Amount                  0
# Transaction_Type                    0
# Time_of_Transaction                 0
# Device_Used                         0
# Location                            0
# Previous_Fraudulent_Transactions    0
# Account_Age                         0
# Number_of_Transactions_Last_24H     0
# Payment_Method                      0
# Fraudulent                          0
# dtype: int64

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50964         T44427     1830             4187.49    Bank Transfer
# 50975         T44680     4877             1826.49      POS Payment
# 50985         T39758     2029              544.53    Bank Transfer
# 50997         T12293     3345             2204.43      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction     Device_Used       Location  \
# 0                     16.0          Tablet  San Francisco
# ...

# %%
plt.figure(figsize=(20, 8))
sns.countplot(x=df['Account_Age'], palette="viridis")
plt.title("Time Period for an Account", fontsize=14)
plt.xlabel("Account Age")
plt.ylabel("Amount")

plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-40-4106999ab52a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Account_Age'], palette="viridis")

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df["Device_Used"], y=df["Location"], palette="coolwarm")
plt.title("Deviced used as per the location", fontsize=14)
plt.xlabel("Devices")
plt.ylabel("Location")
plt.show()
# Out:
# <ipython-input-50-b3088e1de2d1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Device_Used"], y=df["Location"], palette="coolwarm")

# %%
plt.figure(figsize = (12, 8 ))
scatter = plt.scatter(df['Movie_Name'],
                      df['Budget'],
                      alpha = 0.6,
                      cmap = 'viridus')
plt.legend(*scatter.legend_elements(),
           loc = 'upper left',
           title = 'Budget')

plt.xticks(rotation = 45)
plt.title('Scatter-plot-Movie', fontsize = 14, weight = 'bold')
plt.xlabel('Movie-Name', weight = 'bold')
plt.ylabel('Budget')

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
# Thank you
