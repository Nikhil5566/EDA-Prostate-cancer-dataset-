# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/Extrovert_vs_Extrovert_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('personality_dataset.csv')
df.head(11)
# Out:
#     Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                4.0         No                      4.0            6.0
# 1                9.0        Yes                      0.0            0.0
# 2                9.0        Yes                      1.0            2.0
# 3                0.0         No                      6.0            7.0
# 4                3.0         No                      9.0            4.0
# 5                1.0         No                      7.0            5.0
# 6                4.0         No                      9.0            NaN
# 7                2.0         No                      8.0            4.0
# 8               10.0        Yes                      1.0            3.0
# 9                0.0         No                      8.0            6.0
# 10               3.0         No                      9.0            6.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# ...

# %%
df.tail(11)
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 2889               6.0        Yes                      0.0            0.0
# 2890               8.0        Yes                      2.0            0.0
# 2891               6.0        Yes                      3.0            1.0
# 2892               9.0        Yes                      2.0            0.0
# 2893               9.0        NaN                      2.0            0.0
# 2894               0.0         No                      9.0            3.0
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            NaN
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
df.shape
# Out:
# (2900, 8)

# %%
df.columns
# Out:
# Index(['Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
#        'Going_outside', 'Drained_after_socializing', 'Friends_circle_size',
#        'Post_frequency', 'Personality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Time_spent_Alone             float64
# Stage_fear                    object
# Social_event_attendance      float64
# Going_outside                float64
# Drained_after_socializing     object
# Friends_circle_size          float64
# Post_frequency               float64
# Personality                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2837 non-null   float64
#  1   Stage_fear                 2827 non-null   object
#  2   Social_event_attendance    2838 non-null   float64
#  3   Going_outside              2834 non-null   float64
#  4   Drained_after_socializing  2848 non-null   object
#  5   Friends_circle_size        2823 non-null   float64
#  6   Post_frequency             2835 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB

# %%
df.isnull().sum()
# Out:
# Time_spent_Alone             63
# Stage_fear                   73
# Social_event_attendance      62
# Going_outside                66
# Drained_after_socializing    52
# Friends_circle_size          77
# Post_frequency               65
# Personality                   0
# dtype: int64

# %%
# Filling all the missing values:

df.fillna(df.mean(numeric_only = True), inplace = True)

# For categorial Values:
for col in df.select_dtypes(include=['object', 'category']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#         Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# count        2837.000000       2827              2838.000000    2834.000000
# unique               NaN          2                      NaN            NaN
# top                  NaN         No                      NaN            NaN
# freq                 NaN       1417                      NaN            NaN
# mean            4.505816        NaN                 3.963354       3.000000
# std             3.479192        NaN                 2.903827       2.247327
# min             0.000000        NaN                 0.000000       0.000000
# 25%             2.000000        NaN                 2.000000       1.000000
# 50%             4.000000        NaN                 3.000000       3.000000
# 75%             8.000000        NaN                 6.000000       5.000000
# max            11.000000        NaN                10.000000       7.000000
#
# ...

# %% [markdown]
# # Handling Outliers:

# %%
Q1 = df['Social_event_attendance'].quantile(0.25)
Q3 = df['Social_event_attendance'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_outliers = df[(df['Social_event_attendance'] >= lower_bound) & (df['Social_event_attendance'] <= upper_bound)].copy()

print(f'Original Shape: {len(df)}')
print(f'Shape after outlier handling: {len(df_outliers)}')
# Out:
# Original Shape: 2900
# Shape after outlier handling: 2900

# %% [markdown]
# # Univariate Analysis:

# %%
# Get a list of numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# Iterate through numerical columns and create histograms
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# Get a list of categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# Iterate through categorical columns and create countplots
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
    plt.tight_layout() # Adjust layout to prevent labels overlapping
    plt.show()

# You can also use value_counts for a quick look at categorical data distribution
for col in categorical_cols:
    print(f"Value counts for {col}:\n{df[col].value_counts()}\n")
# Out:
# Value counts for Stage_fear:
# Stage_fear
# No     1490
# Yes    1410
# Name: count, dtype: int64
#
# Value counts for Drained_after_socializing:
# Drained_after_socializing
# No     1493
# Yes    1407
# Name: count, dtype: int64
#
# Value counts for Personality:
# Personality
# Extrovert    1491
# Introvert    1409
# Name: count, dtype: int64

# %% [markdown]
# # Bivariate Analysis:

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Time_spent_Alone', y='Stage_fear', data=df)
plt.title('Scatter Plot of Numerical Column 1 vs Numerical Column 2')
plt.xlabel('Time_spent_Alone')
plt.ylabel('Stage_fear')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Drained_after_socializing', y='Post_frequency', data=df)
plt.title('Box Plot of Numerical Column by Categorical Column')
plt.xlabel('Drained_after_socializing')
plt.ylabel('Post_frequency')
plt.show()

# %%
# Generate pair plot for numeric features
df_numeric = df.select_dtypes(include=np.number)
sns.pairplot(df_numeric)
plt.show()

# %%
# Heatmap:

plt.figure(figsize=(15, 6))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %% [markdown]
# # Thank you
