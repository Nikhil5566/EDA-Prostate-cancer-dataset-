# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Prostate-cancer-dataset-/blob/main/Top_Rated_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('top_rated_movies(tmdb).csv')
df.head(11)
# Out:
#          id                        title  \
# 0       278     The Shawshank Redemption
# 1       238                The Godfather
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4   1356039                Counterattack
# 5       389                 12 Angry Men
# 6       129                Spirited Away
# 7     19404  Dilwale Dulhania Le Jayenge
# 8       155              The Dark Knight
# 9       497               The Green Mile
# 10   496243                     Parasite
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   When a hostage rescue mission creates a new en...   2025-02-27
# ...

# %%
df.tail(11)
# Out:
#           id                                             title  \
# 8549    1961                                  My Name Is Bruce
# 8550  348060                                          Antigang
# 8551  156717                               Death Race: Inferno
# 8552   44982                                                13
# 8553   13690                                     Open Season 2
# 8554   11517                                       Money Train
# 8555  291264                                   The Family Fang
# 8556  250349                                          Barbecue
# 8557  150202  The Haunting in Connecticut 2: Ghosts of Georgia
# 8558    4942                                      Leatherheads
# 8559  748167                                            Uglies
#
#                                                overview release_date  \
# 8549  B Movie Legend Bruce Campbell is mistaken for ...   2007-10-01
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.dtypes
# Out:
# id                int64
# title            object
# overview         object
# release_date     object
# popularity      float64
# vote_average    float64
# vote_count        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8560 entries, 0 to 8559
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            8560 non-null   int64
#  1   title         8560 non-null   object
#  2   overview      8560 non-null   object
#  3   release_date  8558 non-null   object
#  4   popularity    8560 non-null   float64
#  5   vote_average  8560 non-null   float64
#  6   vote_count    8560 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 468.3+ KB

# %%
df.describe()
# Out:
#                  id   popularity  vote_average    vote_count
# count  8.560000e+03  8560.000000   8560.000000   8560.000000
# mean   2.082396e+05     3.721817      6.845229   2159.248715
# std    2.768840e+05     0.770182      0.597392   3370.513826
# min    2.000000e+00     0.003000      5.800000    300.000000
# 25%    1.001850e+04     3.533000      6.371000    480.000000
# 50%    3.686550e+04     3.557000      6.800000    903.000000
# 75%    3.861218e+05     3.817000      7.300000   2193.250000
# max    1.356039e+06    29.661000      8.708000  37174.000000

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# id              0
# title           0
# overview        0
# release_date    2
# popularity      0
# vote_average    0
# vote_count      0
# dtype: int64

# %%
df = df.drop(columns=['release_date'])

# %%
duplicate_values = df.duplicated().sum()
duplicate_values
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8560 entries, 0 to 8559
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            8560 non-null   int64
#  1   title         8560 non-null   object
#  2   overview      8560 non-null   object
#  3   popularity    8560 non-null   float64
#  4   vote_average  8560 non-null   float64
#  5   vote_count    8560 non-null   int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 401.4+ KB

# %%
# id vs popularity

df.plot(kind='scatter', x='id', y='popularity', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# vote_average vs vote_count

df.plot(kind='scatter', x='vote_average', y='vote_count', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)
plt.show()

# %%
# Thank you
