# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/social_media_impact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset.csv')
df.head(11)
# Out:
#    What is your age group?    What is your occupation?  Where do you live?   \
# 0                     18-25                     Student          Urban Area
# 1                     18-25                     Student          Urban Area
# 2                     18-25                     Student          Urban Area
# 3                     18-25                     Student          Urban Area
# 4                     18-25                     Student       Suburban Area
# 5                     18-25                     Student       Suburban Area
# 6                     18-25                     Student          Rural Area
# 7                     18-25                     Student          Urban Area
# 8                     18-25                     Student       Suburban Area
# 9                     18-25                     Student          Urban Area
# 10                    18-25                     Student          Rural Area
#
#    How many hours per day do you spend on social media?   \
# 0                                   More than 5 hours
# 1                                           3-5 hours
# 2                                           3-5 hours
# 3                                           3-5 hours
# 4                                           3-5 hours
# 5                                   More than 5 hours
# 6                                   More than 5 hours
# 7                                           3-5 hours
# 8                                           3-5 hours
# 9                                   More than 5 hours
# 10                                          3-5 hours
#
#    How has social media affected your real-life relationships?   \
# 0                                            Improved
# 1                                           No Change
# 2                                           No Change
# 3                                            Worsened
# 4                                            Improved
# 5                                           No Change
# 6                                           No Change
# 7                                           No Change
# 8                                            Improved
# 9                                            Worsened
# 10                                           Worsened
#
#    How frequently do you use email for communication?   \
# 0                                               Daily
# 1                                               Never
# 2                                              Rarely
# 3                                               Never
# 4                                  A few times a week
# 5                                              Rarely
# 6                                              Rarely
# 7                                  A few times a week
# 8                                  A few times a week
# 9                                              Rarely
# 10                                             Rarely
#
#    Do you use LinkedIn for professional networking?    \
# 0                                       Yes, actively
# 1                                           No, never
# 2                                              Rarely
# 3                                           No, never
# 4                                       Yes, actively
# 5                                       Yes, actively
# 6                                              Rarely
# 7                                              Rarely
# 8                                           No, never
# 9                                              Rarely
# 10                                          No, never
#
#    How often do you use WhatsApp for communication?   \
# 0                                              Daily
# 1                                              Daily
# 2                                              Daily
# 3                                              Daily
# 4                                              Daily
# 5                                              Daily
# 6                                              Daily
# 7                                              Daily
# 8                                              Daily
# 9                                 A few times a week
# 10                                A few times a week
#
#    Which social media platforms do you use the most?    \
# 0                                            LinkedIn
# 1                                              Others
# 2                                            Facebook
# 3                                            Facebook
# 4                                            Facebook
# 5                                            LinkedIn
# 6                                           Instagram
# 7                                            Facebook
# 8                                            Facebook
# 9                                            Facebook
# 10                                           Facebook
#
#    Do you feel that social media affects your mental health?
# 0                                     Yes, negatively
# 1                                            Not sure
# 2                                            Not sure
# 3                                     Yes, negatively
# 4                                     Yes, negatively
# 5                                     Yes, positively
# 6                                            Not sure
# 7                                     Yes, positively
# 8                                            Not sure
# 9                                     Yes, negatively
# 10                                    Yes, negatively

# %%
df.tail(11)
# Out:
#    What is your age group?    What is your occupation?  Where do you live?   \
# 38                    18-25                       Other          Urban Area
# 39                    18-25                     Student          Urban Area
# 40                    18-25                     Student          Rural Area
# 41                    18-25                     Student          Rural Area
# 42                    18-25                     Student          Urban Area
# 43                    26-40                    Employee          Rural Area
# 44                    18-25                     Student          Rural Area
# 45                    18-25                     Student          Rural Area
# 46                    18-25                     Student          Urban Area
# 47                    18-25                     Student          Urban Area
# 48                    18-25                  Freelancer          Rural Area
#
#    How many hours per day do you spend on social media?   \
# 38                                  More than 5 hours
# 39                                          3-5 hours
# 40                                  More than 5 hours
# 41                                          1-2 hours
# 42                                          1-2 hours
# 43                                  More than 5 hours
# 44                                          3-5 hours
# 45                                          3-5 hours
# 46                                          3-5 hours
# 47                                  More than 5 hours
# 48                                   Less than 1 hour
#
#    How has social media affected your real-life relationships?   \
# 38                                          No Change
# 39                                          No Change
# 40                                           Worsened
# 41                                           Improved
# 42                                           Worsened
# 43                                           Worsened
# 44                                           Worsened
# 45                                           Worsened
# 46                                           Worsened
# 47                                           Improved
# 48                                          No Change
#
#    How frequently do you use email for communication?   \
# 38                                              Never
# 39                                              Never
# 40                                              Never
# 41                                 A few times a week
# 42                                              Daily
# 43                                 A few times a week
# 44                                             Rarely
# 45                                             Rarely
# 46                                             Rarely
# 47                                 A few times a week
# 48                                 A few times a week
#
#    Do you use LinkedIn for professional networking?    \
# 38                                          No, never
# 39                                          No, never
# 40                                          No, never
# 41                                             Rarely
# 42                                      Yes, actively
# 43                                             Rarely
# 44                                             Rarely
# 45                                          Sometimes
# 46                                          No, never
# 47                                          No, never
# 48                                      Yes, actively
#
#    How often do you use WhatsApp for communication?   \
# 38                                             Never
# 39                                             Daily
# 40                                             Daily
# 41                                             Daily
# 42                                             Daily
# 43                                A few times a week
# 44                                             Daily
# 45                                             Daily
# 46                                             Daily
# 47                                             Daily
# 48                                             Daily
#
#    Which social media platforms do you use the most?    \
# 38                                             Others
# 39                                             Others
# 40                                           Facebook
# 41                                          Instagram
# 42                                           Facebook
# 43                                           Facebook
# 44                                           Facebook
# 45                                           Facebook
# 46                                           Facebook
# 47                                           Facebook
# 48                                           LinkedIn
#
#    Do you feel that social media affects your mental health?
# 38                                           Not sure
# 39                                           Not sure
# 40                                    Yes, negatively
# 41                                           Not sure
# 42                                    Yes, negatively
# 43                                    Yes, negatively
# 44                                           Not sure
# 45                                    Yes, negatively
# 46                                    Yes, negatively
# 47                                    Yes, negatively
# 48                                    Yes, negatively

# %%
df.shape
# Out:
# (49, 10)

# %%
df.columns
# Out:
# Index(['What is your age group? ', '  What is your occupation? ',
#        'Where do you live? ',
#        'How many hours per day do you spend on social media? ',
#        'How has social media affected your real-life relationships? ',
#        'How frequently do you use email for communication? ',
#        'Do you use LinkedIn for professional networking?  ',
#        'How often do you use WhatsApp for communication? ',
#        'Which social media platforms do you use the most?  ',
#        'Do you feel that social media affects your mental health?  '],
#       dtype='object')

# %%
df.dtypes
# Out:
# What is your age group?                                         object
#   What is your occupation?                                      object
# Where do you live?                                              object
# How many hours per day do you spend on social media?            object
# How has social media affected your real-life relationships?     object
# How frequently do you use email for communication?              object
# Do you use LinkedIn for professional networking?                object
# How often do you use WhatsApp for communication?                object
# Which social media platforms do you use the most?               object
# Do you feel that social media affects your mental health?       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   What is your age group?                                       49 non-null     object
#  1     What is your occupation?                                    49 non-null     object
#  2   Where do you live?                                            49 non-null     object
#  3   How many hours per day do you spend on social media?          49 non-null     object
#  4   How has social media affected your real-life relationships?   49 non-null     object
#  5   How frequently do you use email for communication?            49 non-null     object
#  6   Do you use LinkedIn for professional networking?              49 non-null     object
#  7   How often do you use WhatsApp for communication?              49 non-null     object
#  8   Which social media platforms do you use the most?             49 non-null     object
#  9   Do you feel that social media affects your mental health?     49 non-null     object
# dtypes: object(10)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#        What is your age group?    What is your occupation?   \
# count                        49                          49
# unique                        2                           5
# top                       18-25                     Student
# freq                         48                          44
#
#        Where do you live?   \
# count                   49
# unique                   3
# top             Urban Area
# freq                    25
#
#        How many hours per day do you spend on social media?   \
# count                                                  49
# unique                                                  4
# top                                             3-5 hours
# freq                                                   18
#
#        How has social media affected your real-life relationships?   \
# count                                                  49
# unique                                                  3
# top                                             No Change
# freq                                                   17
#
#        How frequently do you use email for communication?   \
# count                                                  49
# unique                                                  4
# top                                                Rarely
# freq                                                   20
#
#        Do you use LinkedIn for professional networking?    \
# count                                                  49
# unique                                                  4
# top                                             No, never
# freq                                                   19
#
#        How often do you use WhatsApp for communication?   \
# count                                                 49
# unique                                                 3
# top                                                Daily
# freq                                                  38
#
#        Which social media platforms do you use the most?    \
# count                                                  49
# unique                                                  4
# top                                              Facebook
# freq                                                   36
#
#        Do you feel that social media affects your mental health?
# count                                                  49
# unique                                                  4
# top                                       Yes, negatively
# freq                                                   23

# %%
df.isnull().sum()
# Out:
# What is your age group?                                         0
#   What is your occupation?                                      0
# Where do you live?                                              0
# How many hours per day do you spend on social media?            0
# How has social media affected your real-life relationships?     0
# How frequently do you use email for communication?              0
# Do you use LinkedIn for professional networking?                0
# How often do you use WhatsApp for communication?                0
# Which social media platforms do you use the most?               0
# Do you feel that social media affects your mental health?       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # visualization
