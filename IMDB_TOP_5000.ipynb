# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil5566/EDA-Repo/blob/main/IMDB_TOP_5000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('imdb_top_5000_tv_shows.csv')
df.head()
# Out:
#       tconst      primaryTitle  startYear  endYear  rank  averageRating  \
# 0  tt0903747      Breaking Bad       2008   2013.0     1            9.5
# 1  tt0185906  Band of Brothers       2001   2001.0     2            9.4
# 2  tt7366338         Chernobyl       2019   2019.0     3            9.3
# 3  tt0795176      Planet Earth       2006   2006.0     4            9.4
# 4  tt5491994   Planet Earth II       2016   2016.0     5            9.4
#
#    numVotes                                          directors  \
# 0   2312017  Michelle MacLaren, Adam Bernstein, Vince Gilli...
# 1    559065  David Frankel, Mikael Salomon, Tom Hanks, Davi...
# 2    942083                                        Johan Renck
# 3    226878                 Alastair Fothergill, Mark Linfield
# 4    165947  Justin Anderson, Ed Charles, Fredi Devas, Chad...
#
#                                              writers  \
# 0  Vince Gilligan, Peter Gould, George Mastras, S...
# ...

# %%
df.tail()
# Out:
#          tconst         primaryTitle  startYear  endYear  rank  averageRating  \
# 4995  tt2882382         Gerçek Kesit       1993   2006.0  4996            7.9
# 4996  tt9165752             Songland       2019   2020.0  4997            8.1
# 4997  tt0165019         The Visitors       1983      NaN  4998            8.2
# 4998  tt0456788  Karanlikta Kosanlar       2001   2001.0  4999            8.5
# 4999  tt0168343  Kérem a következöt!       1975   1986.0  5000            8.1
#
#       numVotes                                          directors  \
# 4995       778                                                  -
# 4996       776                                      Ivan Dudynsky
# 4997       774                                     Jindrich Polák
# 4998       773                                         Ugur Yücel
# 4999       773  József Nepp, Béla Ternovszky, Oszkár Hernádi, ...
#
#                                                 writers  \
# ...

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.columns
# Out:
# Index(['tconst', 'primaryTitle', 'startYear', 'endYear', 'rank',
#        'averageRating', 'numVotes', 'directors', 'writers', 'genres',
#        'IMDbLink', 'Title_IMDb_Link'],
#       dtype='object')

# %%
df.dtypes
# Out:
# tconst              object
# primaryTitle        object
# startYear            int64
# endYear            float64
# rank                 int64
# averageRating      float64
# numVotes             int64
# directors           object
# writers             object
# genres              object
# IMDbLink            object
# Title_IMDb_Link     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# tconst               0
# primaryTitle         0
# startYear            0
# endYear            885
# rank                 0
# averageRating        0
# numVotes             0
# directors            0
# writers              0
# genres               0
# IMDbLink             0
# Title_IMDb_Link      0
# dtype: int64

# %%
# Handling missing values:

df['endYear'] = df['endYear'].fillna(df['endYear'].mean())

# %%
df.isnull().sum()
# Out:
# tconst             0
# primaryTitle       0
# startYear          0
# endYear            0
# rank               0
# averageRating      0
# numVotes           0
# directors          0
# writers            0
# genres             0
# IMDbLink           0
# Title_IMDb_Link    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols].hist(figsize=(14,12), bins=30)
plt.tight_layout()

plt.show()

# %%
# Count shows per start year
plt.figure(figsize=(15, 8))
sns.countplot(data=df, x='startYear', palette='Blues')
plt.title('Distribution of TV Shows by Start Year')
plt.xlabel('Start Year')
plt.ylabel('Number of Shows')
plt.xticks(rotation=70)
plt.show()

# %%
# Distribution of average ratings
plt.figure(figsize=(10, 6))
sns.histplot(df['averageRating'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Get top-rated shows by votes
top_shows = df[df['numVotes'] > 10000].nlargest(20, 'averageRating')

plt.figure(figsize=(12, 6))
sns.barplot(data=top_shows, x='primaryTitle', y='averageRating', palette='viridis')
plt.title('Top 20 Rated Shows by Number of Votes')
plt.xlabel('TV Show')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only = True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix", fontsize=14)

plt.show()

# %%
# Thank you
